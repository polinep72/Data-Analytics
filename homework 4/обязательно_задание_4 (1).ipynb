# %%
# !pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.11.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.5)

# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2023.7.22)

# %%
import pandas as pd
from pandas import DataFrame
from bs4 import BeautifulSoup
from requests import get
import re

# %%
HEADERS={...}
drom_url = 'https://auto.drom.ru/region77/premium/'

#Отправим GET()-запрос на сайт и сохраним полученное в переменную 'page':

page = get(drom_url)

#Проверим подключение:

print(page.status_code)

#Код вернул нам статус код '200', мы успешно подключены
# Out:
# 200

# %%
print(page.content)
# Out:
# b'<!DOCTYPE html>\n<html\n    xmlns="http://www.w3.org/1999/xhtml"\n    lang="ru"\n    xml:lang="ru"\n    class="drom-notouch no-js light no-main0"\n>\n<head>\n                    <title>\xd1\xef\xe5\xf6\xf0\xe0\xe7\xec\xe5\xf9\xe5\xed\xe8\xe5 \xe2 \xcc\xee\xf1\xea\xe2\xe5</title>\n        \n                <meta http-equiv="X-UA-Compatible" content="IE=Edge"/>\n\n        <meta name=\'copyright\' content=\'drom.ru\' />\n<meta name=\'theme-color\' content=\'#000000\' />\n<meta http-equiv=\'Content-Type\' content=\'text/html; charset=windows-1251\' />\n<meta charset=\'windows-1251\' />\n<meta name=\'candy.config\' content=\'{&quot;geor&quot;:77,&quot;geoc&quot;:0,&quot;id&quot;:27,&quot;b&quot;:1,&quot;bc&quot;:1,&quot;charset&quot;:&quot;utf-8&quot;,&quot;cf&quot;:{&quot;category_id&quot;:1}}\' />\n<meta name=\'description\' content=\'\xd7\xe0\xf1\xf2\xed\xfb\xe5 \xee\xe1\xfa\xff\xe2\xeb\xe5\xed\xe8\xff \xee \xef\xf0\xee\xe4\xe0\xe6\xe5 \xe0\xe2\xf2\xee\xec\xee\xe1\xe8\xeb\xe5\xe9 \xed\xe0 Drom.ru (\xd0\xee\xf1\xf1\xe8\xff, \xcc\xee\xf1\xea\xe2\xe0, \xcd\xee\xe2\xee\xf1\xe8\xe1\xe8\xf0\xf1\xea, \xc2\xeb\xe0\xe4\xe8\xe2\xee\xf1\xf2\xee\xea \xe8 \xe4\xf0\xf3\xe3\xe8\xe5 \xe3\xee\xf0\xee\xe4\xe0)\' />\n<meta name=\'keywords\' content=\'\xe0\xe2\xf2\xee, \xe0\xe2\xf2\xee\xec\xee\xe1\xe8\xeb\xe8, \xf4\xee\xf0\xf3\xec\xfb, \xe0\xe2\xf2\xee\xf4\xee\xf0\xf3\xec, \xef\xf0\xee\xe4\xe0\xe6\xe0 \xe1/\xf3, \xef\xf0\xee\xe1\xe5\xe3, \xef\xee\xe4\xe5\xf0\xe6\xe0\xed\xed\xfb\xe5, \xef\xf0\xee\xe4\xe0\xe6\xe0 \xe0\xe2\xf2\xee, \xef\xf0\xee\xe4\xe0\xe6\xe0 \xe0\xe2\xf2\xee\xec\xee\xe1\xe8\xeb\xe5\xe9, \xee\xf2\xe7\xfb\xe2\xfb, \xe0\xe2\xf2\xee\xe2\xeb\xe0\xe4\xe5\xeb\xfc\xf6\xfb, \xee\xe1\xfa\xff\xe2\xeb\xe5\xed\xe8\xff, \xf6\xe5\xed\xfb, \xef\xf0\xee\xe4\xe0\xe6\xe0, toyota, nissan, mitsubishi, honda, mazda, suzuki, subaru, audi, bmw, ford, opel, kia, hyundai, \xea\xe0\xf2\xe0\xeb\xee\xe3\' />\n<meta property="og:image" content="https://c.rdrom.ru/images/og/drom-om.png" /><meta property="og:image:width" content="1200" /><meta property="og:image:height" content="630" /><meta property="og:description" content="\xd7\xe0\xf1\xf2\xed\xfb\xe5 \xee\xe1\xfa\xff\xe2\xeb\xe5\xed\xe8\xff \xee \xef\xf0\xee\xe4\xe0\xe6\xe5 \xe0\xe2\xf2\xee\xec\xee\xe1\xe8\xeb\xe5\xe9 \xed\xe0 Drom.ru (\xd0\xee\xf1\xf1\xe8\xff, \xcc\xee\xf1\xea\xe2\xe0, \xcd\xee\xe2\xee\xf1\xe8\xe1\xe8\xf0\xf1\xea, \xc2\xeb\xe0\xe4\xe8\xe2\xee\xf1\xf2\xee\xea \xe8 \xe4\xf0\xf3\xe3\xe8\xe5 \xe3\xee\xf0\xee\xe4\xe0)" /><meta property="og:title" content="\xd1\xef\xe5\xf6\xf0\xe0\xe7\xec\xe5\xf9\xe5\xed\xe8\xe5 \xe2 \xcc\xee\xf1\xea\xe2\xe5" /><meta property="og:url" content="https://auto.drom.ru/region77/premium/" /><meta property="og:type" content="website" /><meta property="og:site_name" content="\xc4\xf0\xee\xec \xc0\xe2\xf2\xee" /><meta name="twitter:card" content="summary_large_image" /><meta name="twitter:site" content="@dromru" /><meta name="twitter:creator" content="@dromru" />\n                <link rel="preconnect" href="https://c.rdrom.ru" crossorigin>\n        <link rel="preconnect" href="https://s.drom.ru" crossorigin>\n        <link rel="preconnect" href="https://www.googleadservices.com" crossorigin>\n        <link rel="preconnect" href="https://googleads.g.doubleclick.net" crossorigin>\n        <link rel="preconnect" href="https://www.googletagmanager.com" crossorigin>\n        <link rel="preconnect" href="https://www.google-analytics.com" crossorigin>\n        <link rel="preconnect" href="https://www.farpost.ru" crossorigin>\n        <link rel="preconnect" href="https://counter.yadro.ru" crossorigin>\n        <link rel="preconnect" href="https://yummy.drom.ru" crossorigin>\n        <link rel="preconnect" href="https://s2.auto.drom.ru" crossorigin>\n        <link rel="preconnect" href="https://bs-dante.ru" crossorigin>\n\n        \n        \n                    <!-- \xd1\xfe\xe4\xe0 \xea\xeb\xe0\xe4\xf3\xf2\xf1\xff \xf1\xee\xe1\xfb\xf2\xe8\xff, \xea\xee\xf2\xee\xf0\xfb\xe5 \xef\ ...

# %%
#Воспользуемся BeautifulSoup4:
soup = BeautifulSoup(page.content, "html.parser")

# %%
#Парсим по тэгу div чтобы получить данные о всех автомобилях на вкладке Спецразмещение в Москве
all=soup.find_all("div",  class_="css-12lf65q e3qgya0")

for item in all:
  name_car=item.find_all("span", class_="css-1t71ine e16zdi0i0") #Парсим Марки авто и год выпуска по тэгу span
  name_cars=[]
  for p in name_car:
      name_cars.append(p)
  df1 = pd.DataFrame(name_car, columns = ['Марка автомобиля и год выпуска'])
  print(df1)
# Out:
#        Марка автомобиля и год выпуска
# 0                   Mazda Mazda3 2015
# 1                  Geely Monjaro 2023
# 2                     Skoda Yeti 2012
# 3                       Kia Soul 2011
# 4                     Ford Focus 2012
# 5                       RAM 1500 2020
# 6                  Geely Monjaro 2023
# 7                  Infiniti QX80 2020
# 8              Volkswagen Tiguan 2023
# 9   Land Rover Range Rover Sport 2008
# 10                  Nissan Teana 2012
# 11               Volkswagen ID.4 2023
# 12                   Honda Freed 2008
# 13                  Toyota Camry 2018
# 14               Chevrolet Tahoe 2023
# 15                    Mazda CX-5 2019
# 16               Volkswagen ID.4 2023
# 17        Mercedes-Benz GL-Class 2009
# 18       Mercedes-Benz GLS-Class 2022
# 19              Citroen Berlingo 2012
# 20               Volkswagen ID.4 2023
# 21         Mercedes-Benz S-Class 2019
# 22                 Hyundai Creta 2018
# 23             Volkswagen Tiguan 2023
# 24                      BYD Tang 2023
# 25                   Toyota Noah 2018
# 26                     Volvo S60 2021
# 27               Volkswagen ID.4 2022
# 28         Mercedes-Benz G-Class 2006
# 29                   Toyota Tank 2016
# 30            Volkswagen Talagon 2023
# 31                 Porsche Macan 2020
# 32                 Honda Shuttle 2018
# 33             Mercedes-Benz GLC 2023
# 34               Volkswagen ID.4 2022
# 35                  Nissan NV200 2010

# %%
#Парсим Стоимость авто по тэгу div
cost_cars_all = []
for x in soup.find_all('div', class_='css-aimy81 egua2dj0'):

# Очищаем данные
  x1 = re.sub("[^0-9]", "", str(x))
  x2=x1.replace("8120", "")
  x2_s= int(x2)

  cost_cars_all.append(x2_s)
df2 = pd.DataFrame(cost_cars_all, columns = ['Стоимость автомобиля'])
df2
# Out:
#     Стоимость автомобиля
# 0                1780000
# 1                3750000
# 2                1050000
# 3                1150000
# 4                1060000
# 5                7349000
# 6                3700000
# 7                7750000
# 8                5800000
# 9                1590000
# 10               1200000
# 11               5400000
# 12               1119000
# 13               3100000
# 14              11350000
# 15               2440000
# 16               5400000
# 17               1650000
# 18              21999000
# 19               1050000
# 20               5400000
# 21               6490000
# 22               1540000
# 23               5908000
# 24               5300000
# 25               2790000
# 26               3620000
# 27               4598115
# 28               3700000
# 29               1258777
# 30               6700000
# 31               6350000
# 32               1590000
# 33              10199000
# 34               5439000
# 35                995000

# %%
# объединяем DataFrames
df_full = pd.concat([df1, df2], join = 'outer', axis = 1)
print (df_full)
# Out:
#        Марка автомобиля и год выпуска  Стоимость автомобиля
# 0                   Mazda Mazda3 2015               1780000
# 1                  Geely Monjaro 2023               3750000
# 2                     Skoda Yeti 2012               1050000
# 3                       Kia Soul 2011               1150000
# 4                     Ford Focus 2012               1060000
# 5                       RAM 1500 2020               7349000
# 6                  Geely Monjaro 2023               3700000
# 7                  Infiniti QX80 2020               7750000
# 8              Volkswagen Tiguan 2023               5800000
# 9   Land Rover Range Rover Sport 2008               1590000
# 10                  Nissan Teana 2012               1200000
# 11               Volkswagen ID.4 2023               5400000
# 12                   Honda Freed 2008               1119000
# 13                  Toyota Camry 2018               3100000
# 14               Chevrolet Tahoe 2023              11350000
# 15                    Mazda CX-5 2019               2440000
# 16               Volkswagen ID.4 2023               5400000
# 17        Mercedes-Benz GL-Class 2009               1650000
# 18       Mercedes-Benz GLS-Class 2022              21999000
# 19              Citroen Berlingo 2012               1050000
# 20               Volkswagen ID.4 2023               5400000
# 21         Mercedes-Benz S-Class 2019               6490000
# 22                 Hyundai Creta 2018               1540000
# 23             Volkswagen Tiguan 2023               5908000
# 24                      BYD Tang 2023               5300000
# 25                   Toyota Noah 2018               2790000
# 26                     Volvo S60 2021               3620000
# 27               Volkswagen ID.4 2022               4598115
# 28         Mercedes-Benz G-Class 2006               3700000
# 29                   Toyota Tank 2016               1258777
# 30            Volkswagen Talagon 2023               6700000
# 31                 Porsche Macan 2020               6350000
# 32                 Honda Shuttle 2018               1590000
# 33             Mercedes-Benz GLC 2023              10199000
# 34               Volkswagen ID.4 2022               5439000
# 35                  Nissan NV200 2010                995000
